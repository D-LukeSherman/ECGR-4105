# %% [markdown]
# <a href="https://colab.research.google.com/github/D-LukeSherman/ECGR-4105/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
# Out:
# Hello, World!
